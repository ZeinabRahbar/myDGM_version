# %%
! git clone https://github.com/ZeinabRahbar/myDGM_version
# Out:
# Cloning into 'myDGM_version'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (5/5), 497.12 KiB | 4.32 MiB/s, done.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:12
# 🔁 Restarting kernel...

# %%
# !conda create -n DGMenv python=3.8
# !conda activate DGMenv
# !conda install -c anaconda cmake=3.19
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.7.3
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.7.3
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/DGMenv
#
#   added / updated specs:
#     - python=3.8
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.7.22  |       hbcca054_0         146 KB  conda-forge
#     libgcc-ng-13.1.0           |       he5830b7_0         758 KB  conda-forge
#     libgomp-13.1.0             |       he5830b7_0         409 KB  conda-forge
#     libsqlite-3.43.0           |       h2797004_0         821 KB  conda-forge
# ...

# %%
# !conda install -c conda-forge aiohttp==3.8.5 aiosignal==1.3.1 appdirs==1.4.4 asttokens==2.2.1 async-timeout==4.0.2 attrs==23.1.0 backcall==0.2.0 blis==0.7.9 catalogue==2.0.8 certifi==2022.12.7 charset-normalizer==2.1.1 click==8.1.3 cmake==3.25.0 comm==0.1.3 confection==0.0.4 contourpy==1.1.0 cycler==0.11.0 cymem==2.0.7 debugpy==1.6.7 decorator==5.1.1 docker-pycreds==0.4.0 et-xmlfile==1.1.0 executing==1.2.0 filelock==3.9.0 fonttools==4.40.0 frozenlist==1.4.0 fsspec==2023.6.0 gitdb==4.0.10 GitPython==3.1.31 huggingface-hub==0.15.1 idna==3.4 ipykernel==6.23.2 ipython==8.14.0 jedi==0.18.2 Jinja2==3.1.2 joblib==1.2.0 jupyter_client==8.2.0 jupyter_core==5.3.1 keopscore==2.1.2 kiwisolver==1.4.4 langcodes==3.3.0 lightning-utilities==0.9.0 lit==15.0.7 MarkupSafe==2.1.2 matplotlib==3.7.1 matplotlib-inline==0.1.6 mpmath==1.2.1 multidict==6.0.4 murmurhash==1.0.9 nest-asyncio==1.5.6 networkx==3.0 numpy==1.25.0 openpyxl==3.1.2 packaging==23.1 pandas==1.2.5 parso==0.8.3 pathtools==0.1.2 pathy==0.10.2 pexpect==4.8.0 pickleshare==0.7.5 Pillow==9.5.0 platformdirs==3.6.0 preshed==3.0.8 prompt-toolkit==3.0.38 protobuf==4.23.3 psutil==5.9.5 ptyprocess==0.7.0 pure-eval==0.2.2 pybind11==2.11.1 pydantic==1.10.9 pyg-lib==0.2.0+pt20cu118 Pygments==2.15.1 pykeops==1.5.2 pyparsing==3.1.0 python-dateutil==2.8.2 pytorch-lightning==1.9.0 pytz==2023.3 PyYAML==6.0 pyzmq==25.1.0 regex==2023.6 requests==2.28.1 safetensors==0.3.1 scikit-learn==1.2.2 scipy==1.10.1 seaborn==0.12.2 sentry-sdk==1.26.0 setproctitle==1.3.2 six==1.16.0 smart-open==6.3.0 smmap==5.0.0 spacy==3.5.3 spacy-legacy==3.0.12 spacy-loggers==1.0.4 srsly==2.4.6 stack-data==0.6.2 sympy==1.11.1 tensorboardX==2.6.2 thinc==8.1.10 threadpoolctl==3.1.0 tokenizers==0.13.3 torch==1.10.0+cu102 torch-cluster==1.6.1+cu102 torch-geometric==2.3.1 torch-scatter==2.1.1+cu102 torch-sparse==0.6.17+cu102 torch-spline-conv==1.2.2+cu102 torchmetrics==1.0.1 torchvision==0.15.2+cu102 tornado==6.3.2 tqdm==4.65.0 traitlets==5.9.0 transformers==4.30.2 triton==2.0.0

# %%
# !pip install pytorch-lightning==1.2.

# !pip install torch_geometric
# !pip install torch_scatter

# %%
# !pip install pykeops

# %%
import time

start_time = time.time()

# !python /content/myDGM_version/train.py

end_time = time.time()
execution_time = end_time - start_time

print(f"The code took {execution_time} seconds to run.")

# %%
import time

start_time = time.time()

# %cd myDGM_version

# !python /content/myDGM_version/train.py

end_time = time.time()
execution_time = end_time - start_time

print(f"The code took {execution_time} seconds to run.")
